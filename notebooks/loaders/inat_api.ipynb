# %%
import requests
from urllib.parse import quote
from pprint import pprint

# %%
'ecologyiconsofia,edespland,ericaozanick,espen_m,evalunalauze,evlabb,faben,felixdoe,fredbb,gregory-mcgill'
# Out:
# 'ecologyiconsofia,edespland,ericaozanick,espen_m,evalunalauze,evlabb,faben,felixdoe,fredbb,gregory-mcgill'

# %%
response = requests.get('https://api.inaturalist.org/v2/users/', params=params)
