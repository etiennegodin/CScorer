# %%
import duckdb
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from obsq.utils.core import convert_df_to_gdf
path = "/home/manat/projects/obsq/work/dev/data/data.duckdb"
target = 'expert_match'

# %%
table = 'observer'
schema = 'features'
con = duckdb.connect(path)
df = con.execute(f"""SELECT* FROM {schema}.{table}""" ).df()
#df = df.drop(columns= 'geom')
con.close()

# %%
df.shape
# Out:
# (2280, 29)

# %%
def plot_cat_rate(df, cat_col, target = target):
    output = "/home/manat/projects/obsq/work/dev/data/eda/preprocessed"
    rates = (
        df.groupby(cat_col)[target]
        .mean()
        .sort_values()
    )
    sns.barplot(x=rates.index[:20], y=rates.values[:20])
    plt.xticks(rotation=45, ha='right')   # or rotation=60, ha='right'
    plt.title(f"Observations rates for {cat_col}", fontsize=16)
    plt.savefig(f"{output}/{cat_col}_target_rates.jpg", dpi = 300, bbox_inches="tight")

# %%
def plot_logistic_reg(df, x_col:str):

    # Fit logistic regression
    X = sm.add_constant(df[x_col])
    model = sm.Logit(df[target], X).fit(disp=False)
    # Make smooth x grid for curve
    xx = np.linspace(df[x_col].min(), df[x_col].max(), 200)
    XX = sm.add_constant(xx)
    yy = model.predict(XX)
    # Plot
    sns.scatterplot(data=df, x=x_col, y=target, alpha=0.2)
    plt.plot(xx, yy, linewidth=2)
    plt.ylabel("P(y=1 | x)")
    plt.show()

# %%
def plot_mean_response(df, x):
    df.groupby(x)[target].mean().plot(kind="bar")
    plt.ylabel("P(y=1 | x)")
    plt.xlabel("x")
    plt.show()

# %%
def plot_boxplot(df,x_col):
    sns.boxplot(data=df, x=target, y=x_col)

# %%
def reduce_categories(df, col, k=20):
    top = df[col].value_counts().nlargest(k).index
    df[col + "_top"] = df[col].where(df[col].isin(top), "Other")
    return df

# %%
df.describe()
# Out:
#        observations_count    total_pct   expert_ids  expert_ids_pct  \
# count         2280.000000  2280.000000  2280.000000     2280.000000
# mean            17.435965     0.000441     0.827193        0.081927
# std             95.711847     0.002407     3.992968        0.215408
# min              1.000000     0.000030     0.000000        0.000000
# 25%              1.000000     0.000030     0.000000        0.000000
# 50%              3.000000     0.000080     0.000000        0.000000
# 75%              8.000000     0.000200     1.000000        0.010250
# max           3389.000000     0.085250    88.000000        1.000000
#
#        expert_match_count  expert_match_pct  avg_id_time  class_count  \
# count         2280.000000       2280.000000  2280.000000  2280.000000
# mean             0.207895          0.043889    32.442544     1.835965
# std              0.405890          0.155639   102.279016     1.066596
# min              0.000000          0.000000     0.000000     1.000000
# 25%              0.000000          0.000000     0.000000     1.000000
# 50%              0.000000          0.000000     1.500000     1.000000
# 75%              0.000000          0.000000    16.000000     2.000000
# max              1.000000          1.000000  1455.000000     5.000000
#
#        order_count  family_count  ...  high_cood_un_obs  high_cood_un_pct  \
# count  2280.000000   2280.000000  ...       2280.000000       2280.000000
# mean      5.160088      6.838596  ...          0.356140          0.047257
# std       6.542753     11.490130  ...          1.399996          0.171280
# min       1.000000      1.000000  ...          0.000000          0.000000
# 25%       1.000000      1.000000  ...          0.000000          0.000000
# 50%       2.000000      2.000000  ...          0.000000          0.000000
# 75%       6.000000      7.000000  ...          0.000000          0.000000
# max      39.000000     97.000000  ...         19.000000          1.000000
#
#        avg_coord_un  avg_media_count  sex_meta_pct  \
# count   2280.000000      2280.000000   2280.000000
# mean     155.051035        14.329491      0.007378
# std      380.310347         9.051353      0.064094
# min        0.000000         0.000000      0.000000
# 25%        6.000000        10.000000      0.000000
# 50%       18.410500        10.000000      0.000000
# 75%       92.250000        15.710000      0.000000
# max     2946.000000       112.000000      1.000000
#
#        reproductiveCondition_meta_pct  annotations_meta_pct  \
# count                     2280.000000           2280.000000
# mean                         0.107499              0.037505
# std                          0.235492              0.136973
# min                          0.000000              0.000000
# 25%                          0.000000              0.000000
# 50%                          0.000000              0.000000
# 75%                          0.091000              0.000000
# max                          1.000000              1.000000
#
#        avg_description_len  avg_species_obs_count  max_species_obs_count
# count          2280.000000            2280.000000            2280.000000
# mean              4.669737               1.150974               1.829386
# std              21.003336               1.973951               6.181496
# min               0.000000               1.000000               1.000000
# 25%               0.000000               1.000000               1.000000
# 50%               0.000000               1.000000               1.000000
# 75%               0.000000               1.000000               1.000000
# max             294.000000              92.000000             198.000000
#
# [8 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2280 entries, 0 to 2279
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   recordedBy                      2280 non-null   object
#  1   observations_count              2280 non-null   int64
#  2   total_pct                       2280 non-null   float64
#  3   expert_ids                      2280 non-null   int64
#  4   expert_ids_pct                  2280 non-null   float64
#  5   expert_match_count              2280 non-null   int64
#  6   expert_match_pct                2280 non-null   float64
#  7   avg_id_time                     2280 non-null   float64
#  8   class_count                     2280 non-null   int64
#  9   order_count                     2280 non-null   int64
#  10  family_count                    2280 non-null   int64
#  11  genus_count                     2280 non-null   int64
#  12  species_count                   2280 non-null   int64
#  13  unique_year_count               2280 non-null   int64
#  14  unique_dates                    2280 non-null   int64
#  15  max_yearly_observations         2280 non-null   int64
#  16  max_monthly_observations        2280 non-null   int64
#  17  avg_yearly_observations         2280 non-null   float64
#  18  avg_monthly_observations        2280 non-null   float64
#  19  high_cood_un_obs                2280 non-null   int64
#  20  high_cood_un_pct                2280 non-null   float64
#  21  avg_coord_un                    2280 non-null   float64
#  22  avg_media_count                 2280 non-null   float64
#  23  sex_meta_pct                    2280 non-null   float64
#  24  reproductiveCondition_meta_pct  2280 non-null   float64
#  25  annotations_meta_pct            2280 non-null   float64
#  26  avg_description_len             2280 non-null   float64
#  27  avg_species_obs_count           2280 non-null   float32
#  28  max_species_obs_count           2280 non-null   int32
# dtypes: float32(1), float64(13), int32(1), int64(13), object(1)
# memory usage: 498.9+ KB

# %%
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# recordedBy                        0
# observations_count                0
# total_pct                         0
# expert_ids                        0
# expert_ids_pct                    0
# expert_match_count                0
# expert_match_pct                  0
# avg_id_time                       0
# class_count                       0
# order_count                       0
# family_count                      0
# genus_count                       0
# species_count                     0
# unique_year_count                 0
# unique_dates                      0
# max_yearly_observations           0
# max_monthly_observations          0
# avg_yearly_observations           0
# avg_monthly_observations          0
# high_cood_un_obs                  0
# high_cood_un_pct                  0
# avg_coord_un                      0
# avg_media_count                   0
# sex_meta_pct                      0
# reproductiveCondition_meta_pct    0
# annotations_meta_pct              0
# avg_description_len               0
# avg_species_obs_count             0
# max_species_obs_count             0
# dtype: int64
