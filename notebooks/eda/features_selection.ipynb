# %%
import duckdb
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

path = "/home/etienne/projects/obsq/work/dev/data/data.duckdb"
target = 'expert_match'

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
table = 'combined'
schema = 'features'
con = duckdb.connect(path)
df = con.execute(f"""SELECT* FROM {schema}.{table}""" ).df()
#df = df.drop(columns= 'geom')
con.close()

# %%
df_pos = df[df['expert_match'] == 1]
df_neg = df[df['expert_match'] == 0]

# %%
#Set index from gbifID
df = df.set_index('gbifID')

# %%
def plot_mean_response(df, x):
    df.groupby(x)[target].mean().plot(kind="bar")
    plt.ylabel("P(y=1 | x)")
    plt.xlabel("x")
    plt.show()

# %%
def plot_3d_df(df):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    # 4. Plot the data using Matplotlib's 3D function
    # You can use a Seaborn color palette here as a colormap for the 'c' argument
    scatter = ax.scatter(df.iloc[:,0], df.iloc[:,1], df.iloc[:,2], 
                        
                        s=50) # 's' controls marker size
    ax.set_xlabel("pca_0")
    ax.set_ylabel("pca_1")
    ax.set_zlabel("pca_2")

# %%
def plot_cat_rate(df, cat_col):
    output = "home/etienne/projects/obsq/eda"
    rates = (
        df.groupby(cat_col)[target]
        .mean()
        .sort_values()
    )
    sns.barplot(x=rates.index[:20], y=rates.values[:20])
    plt.xticks(rotation=45, ha='right')   # or rotation=60, ha='right'
    plt.title(f"Observations rates for {cat_col}", fontsize=16)
    plt.savefig(f"{output}/{cat_col}_target_rates.jpg", dpi = 300, bbox_inches="tight")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36164 entries, 4952691517 to 3759271213
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   expert_match                        36164 non-null  int32
#  1   species                             36164 non-null  object
#  2   observer_pca0                       36164 non-null  float64
#  3   observer_pca1                       36164 non-null  float64
#  4   histo_taxon_ttl_obs_count           36164 non-null  int32
#  5   histo_taxon_obs_month_density       36164 non-null  float32
#  6   cmva_id_count                       36164 non-null  int64
#  7   cmva_id_agree_rate                  36163 non-null  float64
#  8   cmva_id_time                        36164 non-null  int64
#  9   cmva_expert_id                      36164 non-null  int32
#  10  tempo_day                           36164 non-null  int64
#  11  tempo_month                         36164 non-null  int64
#  12  tempo_year                          36164 non-null  int64
#  13  tempo_eventDate                     36164 non-null  object
#  14  meta_media_count                    36164 non-null  int32
#  15  meta_coordinateUncertaintyInMeters  36164 non-null  int32
#  16  meta_pheno_repro                    36164 non-null  int32
#  17  meta_pheno_leaves                   36164 non-null  int32
#  18  meta_pheno_sex                      36164 non-null  int32
#  19  meta_occurrenceRemarks              36164 non-null  int64
#  20  pheno_leaves_month_density          1683 non-null   float32
#  21  pheno_sex_month_density             76 non-null     float32
#  22  pheno_repro_month_density           2847 non-null   float32
#  23  taxo_freq                           36164 non-null  float64
#  24  taxo_confusability_index            36164 non-null  int64
#  25  gee_pca0                            36164 non-null  float64
#  26  gee_pca1                            36164 non-null  float64
#  27  gee_pca2                            36164 non-null  float64
#  28  gee_pca3                            36164 non-null  float64
#  29  spatial_cluster                     36164 non-null  int32
# dtypes: float32(4), float64(8), int32(9), int64(7), object(2)
# memory usage: 6.8+ MB

# %%
df.describe()
# Out:
#        expert_match  observer_pca0  observer_pca1  histo_taxon_ttl_obs_count  \
# count   36164.00000    36164.00000    36164.00000                36164.00000
# mean        0.06675      -54.62962      395.32505                  517.32201
# std         0.24959      206.98976      614.24264                 1306.88818
# min         0.00000     -161.70439      -21.45291                    6.00000
# 25%         0.00000     -150.50913       23.76387                    6.00000
# 50%         0.00000     -132.88400      129.03148                    6.00000
# 75%         0.00000      -58.17582      384.08067                    6.00000
# max         1.00000     2791.00880     1933.89562                 7839.00000
#
#        histo_taxon_obs_month_density  cmva_id_count  cmva_id_agree_rate  \
# count                    36164.00000    36164.00000         36163.00000
# mean                         0.17508        1.23460             0.99878
# std                          0.26377        0.52231             0.01756
# min                          0.00000        0.00000             0.66670
# 25%                          0.00000        1.00000             1.00000
# 50%                          0.00000        1.00000             1.00000
# 75%                          0.29861        1.00000             1.00000
# max                          0.84536        7.00000             1.00000
#
#        cmva_id_time  cmva_expert_id   tempo_day  ...  \
# count   36164.00000     36164.00000 36164.00000  ...
# mean       22.88240         0.04811    15.89326  ...
# std        99.21467         0.21401     9.21334  ...
# min         0.00000         0.00000     1.00000  ...
# 25%         0.00000         0.00000     7.00000  ...
# 50%         1.00000         0.00000    16.00000  ...
# 75%         3.00000         0.00000    24.00000  ...
# max      1618.00000         1.00000    31.00000  ...
#
#        pheno_leaves_month_density  pheno_sex_month_density  \
# count                  1683.00000                 76.00000
# mean                      0.29691                  0.50489
# std                       0.20354                  0.27158
# min                       0.00600                  0.02700
# 25%                       0.14700                  0.23600
# 50%                       0.24300                  0.56600
# 75%                       0.38500                  0.60900
# max                       1.00000                  1.00000
#
#        pheno_repro_month_density   taxo_freq  taxo_confusability_index  \
# count                 2847.00000 36164.00000               36164.00000
# mean                     0.29900     0.79969                   4.05821
# std                      0.27191     1.60529                   7.75600
# min                      0.00000     0.00100                   0.00000
# 25%                      0.08900     0.04600                   0.00000
# 50%                      0.19700     0.13500                   0.00000
# 75%                      0.51700     0.49800                   3.00000
# max                      1.00000     9.37100                  24.00000
#
#          gee_pca0    gee_pca1    gee_pca2    gee_pca3  spatial_cluster
# count 36164.00000 36164.00000 36164.00000 36164.00000      36164.00000
# mean      0.01769    -0.01239    -0.00984     0.00163          2.63287
# std     144.77226    41.37677    16.95808    10.54791          1.70762
# min    -199.00847  -194.28831   -95.87271   -45.65685          0.00000
# 25%    -139.15238    -9.84309   -11.73240    -5.25413          1.00000
# 50%     -20.21458     5.97727     5.30538     1.29059          3.00000
# 75%      95.36073    13.12262    11.84674     8.62983          4.00000
# max     860.65115   155.52897    37.35730    29.62334          5.00000
#
# [8 rows x 28 columns]

# %%
df.var(numeric_only = True).sort_values(ascending=False)
# Out:
# histo_taxon_ttl_obs_count            1707956.72674
# observer_pca1                         377294.01657
# meta_coordinateUncertaintyInMeters    117994.80045
# observer_pca0                          42844.76087
# gee_pca0                               20959.00591
# cmva_id_time                            9843.55050
# gee_pca1                                1712.03721
# meta_occurrenceRemarks                  1170.80985
# gee_pca2                                 287.57664
# meta_media_count                         156.83798
# gee_pca3                                 111.25846
# tempo_day                                 84.88560
# taxo_confusability_index                  60.15548
# spatial_cluster                            2.91598
# taxo_freq                                  2.57694
# tempo_year                                 2.03698
# tempo_month                                1.57220
# cmva_id_count                              0.27281
# meta_pheno_repro                           0.13566
# meta_pheno_leaves                          0.09413
# pheno_repro_month_density                  0.07393
# pheno_sex_month_density                    0.07376
# histo_taxon_obs_month_density              0.06958
# expert_match                               0.06230
# cmva_expert_id                             0.04580
# pheno_leaves_month_density                 0.04143
# meta_pheno_sex                             0.00355
# cmva_id_agree_rate                         0.00031
# dtype: float64

# %%
corr = df.corr(numeric_only=True)
upper_tri = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))

sns.heatmap(upper_tri, cmap='Blues',)
# Out:
# <Axes: >

# %%
highly_correlated_pairs = upper_tri.stack().sort_values(ascending=False)
highly_correlated_pairs
# Out:
# taxo_freq                      taxo_confusability_index              0.84189
# pheno_sex_month_density        pheno_repro_month_density             0.72859
# observer_pca0                  meta_coordinateUncertaintyInMeters    0.59937
# meta_pheno_repro               meta_pheno_leaves                     0.55583
# pheno_leaves_month_density     pheno_repro_month_density             0.48751
#                                                                       ...
# gee_pca0                       spatial_cluster                      -0.32126
# cmva_id_count                  cmva_id_agree_rate                   -0.37848
# tempo_month                    pheno_sex_month_density              -0.47677
# histo_taxon_obs_month_density  tempo_month                          -0.47798
# gee_pca2                       spatial_cluster                      -0.51217
# Length: 375, dtype: float64

# %%
to_drop = [column for column in upper_tri.columns if any(upper_tri[column].abs() > 0.8)]
to_drop
# Out:
# ['taxo_confusability_index']

# %%
columns = df.select_dtypes(include='number').columns.tolist()
print(len(columns))

strong_sep = []
moderate_sep = []
low_sep = []
skip = ['gbifID', 'expert_match']

for c in columns:
    if c in skip:
        continue 
    pos_mean = df_pos[c].mean()
    neg_mean = df_neg[c].mean()
    pos_std = df_pos[c].std()
    cohens_d = (pos_mean - neg_mean) / pos_std
    print(f"\n{c}: ", round(abs(cohens_d),3))
    if abs(cohens_d) > 0.5:
        print("  ✓ Strong separation - likely useful!")
        strong_sep.append(c)
    elif abs(cohens_d) > 0.2:
        print("  ⚠ Moderate separation - may be useful")
        moderate_sep.append(c)
    else:
        print("  ✗ Weak separation - may not help")
        low_sep.append(c)
# Out:
# 28
#
# observer_pca0:  0.09
#   ✗ Weak separation - may not help
#
# observer_pca1:  0.463
#   ⚠ Moderate separation - may be useful
#
# histo_taxon_ttl_obs_count:  0.053
#   ✗ Weak separation - may not help
#
# histo_taxon_obs_month_density:  0.265
#   ⚠ Moderate separation - may be useful
#
# cmva_id_count:  0.183
#   ✗ Weak separation - may not help
#
# cmva_id_agree_rate:  0.025
#   ✗ Weak separation - may not help
#
# cmva_id_time:  0.05
#   ✗ Weak separation - may not help
#
# cmva_expert_id:  0.056
#   ✗ Weak separation - may not help
#
# tempo_day:  0.006
#   ✗ Weak separation - may not help
#
# tempo_month:  0.425
#   ⚠ Moderate separation - may be useful
#
# tempo_year:  0.013
#   ✗ Weak separation - may not help
#
# meta_media_count:  0.036
#   ✗ Weak separation - may not help
#
# meta_coordinateUncertaintyInMeters:  0.013
#   ✗ Weak separation - may not help
#
# meta_pheno_repro:  0.058
#   ✗ Weak separation - may not help
#
# meta_pheno_leaves:  0.127
#   ✗ Weak separation - may not help
#
# meta_pheno_sex:  0.003
#   ✗ Weak separation - may not help
#
# meta_occurrenceRemarks:  0.056
#   ✗ Weak separation - may not help
#
# pheno_leaves_month_density:  0.192
#   ✗ Weak separation - may not help
#
# pheno_sex_month_density:  0.595
#   ✓ Strong separation - likely useful!
#
# pheno_repro_month_density:  0.024
#   ✗ Weak separation - may not help
#
# taxo_freq:  0.009
#   ✗ Weak separation - may not help
#
# taxo_confusability_index:  0.057
#   ✗ Weak separation - may not help
#
# gee_pca0:  0.102
#   ✗ Weak separation - may not help
#
# gee_pca1:  0.274
#   ⚠ Moderate separation - may be useful
#
# gee_pca2:  0.163
#   ✗ Weak separation - may not help
#
# gee_pca3:  0.174
#   ✗ Weak separation - may not help
#
# spatial_cluster:  0.627
#   ✓ Strong separation - likely useful!

# %%
strong_sep
# Out:
# ['pheno_sex_month_density', 'spatial_cluster']

# %%
moderate_sep
# Out:
# 4
# ['observer_pca1', 'histo_taxon_obs_month_density', 'tempo_month', 'gee_pca1']

# %%
low_sep
# Out:
# ['observer_pca0',
#  'histo_taxon_ttl_obs_count',
#  'cmva_id_count',
#  'cmva_id_agree_rate',
#  'cmva_id_time',
#  'cmva_expert_id',
#  'tempo_day',
#  'tempo_year',
#  'meta_media_count',
#  'meta_coordinateUncertaintyInMeters',
#  'meta_pheno_repro',
#  'meta_pheno_leaves',
#  'meta_pheno_sex',
#  'meta_occurrenceRemarks',
#  'pheno_leaves_month_density',
#  'pheno_repro_month_density',
#  'taxo_freq',
#  'taxo_confusability_index',
#  'gee_pca0',
#  'gee_pca2',
#  'gee_pca3']

# %%
species_col = 'species'
species_counts = df[species_col].value_counts()
rare_threshold = len(df) * 0.01  # Species with <1% of observations
species_mapped = df[species_col].apply(
    lambda x: x if species_counts[x] >= rare_threshold else 'rare_species'
)
species_index, species_labels,  = pd.factorize(species_mapped)
df['species_encoded'] =
# Out:
#             expert_match                 species  observer_pca0  \
# gbifID
# 4952691517             0        Actaea pachypoda     -161.70439
# 5134071604             0       Populus deltoides     -161.70439
# 5292748633             0            Rubus idaeus      -69.42477
# 5206462574             0     Persicaria maculosa     -120.18900
# 4978265028             0      Alliaria petiolata     -161.70439
# ...                  ...                     ...            ...
# 3455825209             0            Acer negundo     -155.87174
# 4936428726             0      Juniperus communis     -149.83100
# 4868108385             0            Acer negundo     -156.84272
# 4891657273             0  Fraxinus pennsylvanica     -156.84272
# 3759271213             0      Celastrus scandens      213.78924
#
#             observer_pca1  histo_taxon_ttl_obs_count  \
# gbifID
# 4952691517     1933.89562                       1062
# 5134071604     1933.89562                          6
# 5292748633      292.10692                          6
# 5206462574       10.12328                          6
# 4978265028     1933.89562                          6
# ...                   ...                        ...
# 3455825209      101.64567                       3744
# 4936428726       26.98640                          6
# 4868108385      719.75525                       3744
# 4891657273      719.75525                          6
# 3759271213      218.66882                        298
#
#             histo_taxon_obs_month_density  cmva_id_count  cmva_id_agree_rate  \
# gbifID
# 4952691517                        0.09040              1             1.00000
# 5134071604                        0.00000              1             1.00000
# 5292748633                        0.00000              1             1.00000
# 5206462574                        0.66667              1             1.00000
# 4978265028                        0.00000              1             1.00000
# ...                                   ...            ...                 ...
# 3455825209                        0.09268              1             1.00000
# 4936428726                        0.00000              1             1.00000
# 4868108385                        0.19685              1             1.00000
# 4891657273                        0.66667              1             1.00000
# 3759271213                        0.05705              1             1.00000
#
#             cmva_id_time  cmva_expert_id  ...  pheno_leaves_month_density  \
# gbifID                                    ...
# 4952691517            10               0  ...                     0.20000
# 5134071604             5               0  ...                     0.22900
# 5292748633            12               0  ...                     0.18900
# 5206462574             2               0  ...                     0.05300
# 4978265028             3               0  ...                     0.09100
# ...                  ...             ...  ...                         ...
# 3455825209             0               0  ...                         NaN
# 4936428726             1               0  ...                     0.16400
# 4868108385             1               0  ...                     0.19300
# 4891657273             1               0  ...                     0.12900
# 3759271213             1               0  ...                         NaN
#
#             pheno_sex_month_density  pheno_repro_month_density taxo_freq  \
# gbifID
# 4952691517                      NaN                    0.14400   0.05700
# 5134071604                      NaN                    0.05500   2.74300
# 5292748633                      NaN                    0.76700   1.61900
# 5206462574                      NaN                    0.12500   0.01000
# 4978265028                      NaN                    0.23800   0.12600
# ...                             ...                        ...       ...
# 3455825209                      NaN                    0.04800   9.37100
# 4936428726                  0.33300                        NaN   0.00500
# 4868108385                  0.39100                        NaN   9.37100
# 4891657273                  0.04500                        NaN   0.06700
# 3759271213                  0.03900                        NaN   0.00300
#
#             taxo_confusability_index   gee_pca0  gee_pca1  gee_pca2  gee_pca3  \
# gbifID
# 4952691517                         0   -5.74652   3.66671   9.38831  10.82902
# 5134071604                        24  -44.84367  10.69111   8.18523   7.58560
# 5292748633                        24 -145.79223   3.55552 -16.85087   5.17230
# 5206462574                         0  -93.42302  -0.09138  16.17648  12.09848
# 4978265028                         0   67.41128  -8.42319   6.87742  13.50345
# ...                              ...        ...       ...       ...       ...
# 3455825209                        24 -154.54382   3.19284 -25.28399   0.16299
# 4936428726                         0  370.22071 -77.13658 -28.23889 -16.30112
# 4868108385                        24 -162.14117   9.09773 -18.45419  -1.66272
# 4891657273                         0 -158.68874   7.25616 -19.56078  -2.69841
# 3759271213                         0 -162.58919 -75.45996  -6.79002  -3.05679
#
#             spatial_cluster
# gbifID
# 4952691517                1
# 5134071604                1
# 5292748633                5
# 5206462574                1
# 4978265028                1
# ...                     ...
# 3455825209                5
# 4936428726                0
# 4868108385                5
# 4891657273                5
# 3759271213                2
#
# [36164 rows x 30 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    roc_auc_score,
    precision_recall_curve,
    auc,
    f1_score
)
from sklearn.metrics import RocCurveDisplay, confusion_matrix, ConfusionMatrixDisplay, PrecisionRecallDisplay, precision_recall_curve
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
col = strong_sep + moderate_sep + low_sep
X = df[col].fillna(0)
y = df[target]
X
# Out:
#             pheno_sex_month_density  spatial_cluster  observer_pca1  \
# gbifID
# 4952691517                  0.00000                1     1933.89562
# 5134071604                  0.00000                1     1933.89562
# 5292748633                  0.00000                5      292.10692
# 5206462574                  0.00000                1       10.12328
# 4978265028                  0.00000                1     1933.89562
# ...                             ...              ...            ...
# 3455825209                  0.00000                5      101.64567
# 4936428726                  0.33300                0       26.98640
# 4868108385                  0.39100                5      719.75525
# 4891657273                  0.04500                5      719.75525
# 3759271213                  0.03900                2      218.66882
#
#             histo_taxon_obs_month_density  tempo_month  gee_pca1  \
# gbifID
# 4952691517                        0.09040            7   3.66671
# 5134071604                        0.00000            4  10.69111
# 5292748633                        0.00000            7   3.55552
# 5206462574                        0.66667            5  -0.09138
# 4978265028                        0.00000            7  -8.42319
# ...                                   ...          ...       ...
# 3455825209                        0.09268            8   3.19284
# 4936428726                        0.00000            8 -77.13658
# 4868108385                        0.19685            5   9.09773
# 4891657273                        0.66667            5   7.25616
# 3759271213                        0.05705            4 -75.45996
#
#             observer_pca0  histo_taxon_ttl_obs_count  cmva_id_count  \
# gbifID
# 4952691517     -161.70439                       1062              1
# 5134071604     -161.70439                          6              1
# 5292748633      -69.42477                          6              1
# 5206462574     -120.18900                          6              1
# 4978265028     -161.70439                          6              1
# ...                   ...                        ...            ...
# 3455825209     -155.87174                       3744              1
# 4936428726     -149.83100                          6              1
# 4868108385     -156.84272                       3744              1
# 4891657273     -156.84272                          6              1
# 3759271213      213.78924                        298              1
#
#             cmva_id_agree_rate  ...  meta_pheno_leaves  meta_pheno_sex  \
# gbifID                          ...
# 4952691517             1.00000  ...                  1               0
# 5134071604             1.00000  ...                  1               0
# 5292748633             1.00000  ...                  1               0
# 5206462574             1.00000  ...                  1               0
# 4978265028             1.00000  ...                  1               0
# ...                        ...  ...                ...             ...
# 3455825209             1.00000  ...                  0               0
# 4936428726             1.00000  ...                  1               1
# 4868108385             1.00000  ...                  1               1
# 4891657273             1.00000  ...                  1               1
# 3759271213             1.00000  ...                  0               1
#
#             meta_occurrenceRemarks  pheno_leaves_month_density  \
# gbifID
# 4952691517                       0                     0.20000
# 5134071604                       0                     0.22900
# 5292748633                       0                     0.18900
# 5206462574                       0                     0.05300
# 4978265028                       0                     0.09100
# ...                            ...                         ...
# 3455825209                       0                     0.00000
# 4936428726                      14                     0.16400
# 4868108385                      69                     0.19300
# 4891657273                       0                     0.12900
# 3759271213                       0                     0.00000
#
#             pheno_repro_month_density  taxo_freq  taxo_confusability_index  \
# gbifID
# 4952691517                    0.14400    0.05700                         0
# 5134071604                    0.05500    2.74300                        24
# 5292748633                    0.76700    1.61900                        24
# 5206462574                    0.12500    0.01000                         0
# 4978265028                    0.23800    0.12600                         0
# ...                               ...        ...                       ...
# 3455825209                    0.04800    9.37100                        24
# 4936428726                    0.00000    0.00500                         0
# 4868108385                    0.00000    9.37100                        24
# 4891657273                    0.00000    0.06700                         0
# 3759271213                    0.00000    0.00300                         0
#
#              gee_pca0  gee_pca2  gee_pca3
# gbifID
# 4952691517   -5.74652   9.38831  10.82902
# 5134071604  -44.84367   8.18523   7.58560
# 5292748633 -145.79223 -16.85087   5.17230
# 5206462574  -93.42302  16.17648  12.09848
# 4978265028   67.41128   6.87742  13.50345
# ...               ...       ...       ...
# 3455825209 -154.54382 -25.28399   0.16299
# 4936428726  370.22071 -28.23889 -16.30112
# 4868108385 -162.14117 -18.45419  -1.66272
# 4891657273 -158.68874 -19.56078  -2.69841
# 3759271213 -162.58919  -6.79002  -3.05679
#
# [36164 rows x 27 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
n_samples = len(y_train)
n_pos = y_train.sum()
n_neg = n_samples - n_pos
scale_pos_weight = n_neg / n_pos

# %%
model = LogisticRegression(solver='liblinear', class_weight='balanced',max_iter=1000, random_state=0) # 'lbfgs' is default in newer versions

# %%
model = RandomForestClassifier(
                n_estimators=500,
                class_weight='balanced',
                max_depth=10,
                random_state=42,
                n_jobs=-1
            )

# %%
model = XGBClassifier(
                n_estimators=500,
                max_depth=7,
                scale_pos_weight=scale_pos_weight,
                learning_rate=0.1,
                random_state=42,
                eval_metric='logloss')

# %%
model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_test_scaled)
y_proba = model.predict_proba(X_test_scaled)[:, 1]

# Evaluate the model (e.g., accuracy, confusion matrix, classification report)
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", metrics.confusion_matrix(y_test, y_pred))
print("Classification Report:\n", metrics.classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9385023780555248
# Confusion Matrix:
#  [[8120  317]
#  [ 239  365]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.97      8437
#            1       0.54      0.60      0.57       604
#
#     accuracy                           0.94      9041
#    macro avg       0.75      0.78      0.77      9041
# weighted avg       0.94      0.94      0.94      9041

# %%
precision, recall, _ = precision_recall_curve(y_test, y_proba)
print('roc_auc', roc_auc_score(y_test, y_proba))
print('pr_auc', auc(recall, precision))
# Out:
# roc_auc 0.9111726611025073
# pr_auc 0.6032945884757819

# %%
precision, recall, _ = precision_recall_curve(y_test, y_pred)
PrecisionRecallDisplay.from_estimator(
   model, X_test_scaled, y_test)

# %%
RocCurveDisplay.from_estimator(model, X_test_scaled, y_test)

# %%
y_pred = model.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot(cmap='Blues')
