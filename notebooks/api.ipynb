# %%
from obsq.data.ingest.inat.api import inatObservationApi
id = {'id' : 285951663}
request = inatObservationApi('id_request', 285951663)
data = await request.request()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       3 id = {'id' : 285951663}
#       4 request = inatObservationApi('id_request', 285951663)
# ----> 5 data = await request.request()
#
# File ~/projects/obsq/src/obsq/data/ingest/inat/api.py:34, in inatObservationApi.request(self)
#      31 async def request(self):
#      33     async with aiohttp.ClientSession() as session:
# ---> 34         async with session.get(self.url, params=self.fields, timeout=10) as r:
#      35                             r.url
#      36                             r.raise_for_status()
#
# AttributeError: 'inatObservationApi' object has no attribute 'url'

# %%
data
# Out:
# <coroutine object inatObservationApi.request at 0x7427863d2540>
