# %%
from Cscorer.core import read_config

from shapely import wkt
path = "/home/manat/projects/CScorer/work/dev/config.yaml"

config = read_config(path)
geo = config['gbif']['GEOMETRY']
geom = wkt.loads(geo)
minx, miny, maxx, maxy = geom.bounds

# South-West and North-East
lat_so, lon_so = miny, minx
lat_ne, lon_ne = maxy, maxx

print(lat_so, lon_so )
print(lat_ne, lon_ne)

x = "quality_grade=research&identifications=any&captive=false&swlat=45.014526+&swlng=-74.519611&nelat=46.821866+&nelng=-70.203212&taxon_id=211194"
# Out:
# 45.014526 -74.519611
# 46.821866 -70.203212
