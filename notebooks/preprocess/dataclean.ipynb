# %%
import duckdb
db_path = "/home/manat/projects/obsq/work/dev/data/data.duckdb"

# %%
from obsq.utils.duckdb import import_csv_to_db, _open_connection

with _open_connection(db_path)

# %%
citizen_path = "/home/manat/projects/obsq/work/dev/data/gbif/0027014-251025141854904.csv"
expert_path = "/home/manat/projects/obsq/work/dev/data/gbif/0027013-251025141854904.csv"

# %%
await import_csv_to_db(con, citizen_path, "raw", 'gbif_citizen', geo = True)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/manat/projects/obsq/src/obsq/utils/duckdb.py", line 45, in import_csv_to_db
#     con.execute(query)
# _duckdb.CatalogException: Catalog Error: Scalar Function with name "st_point" is not in the catalog, but it exists in the spatial extension.
#
# Please try installing and loading the spatial extension:
# INSTALL spatial;
# LOAD spatial;
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/manat/miniconda3/envs/obsq/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/manat/miniconda3/envs/obsq/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/manat/miniconda3/envs/obsq/lib/python3.11/logging/__init__.py", line 687, in format
# ...

# %%
con.close()
