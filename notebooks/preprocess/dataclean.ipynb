# %%
import duckdb
con = duckdb.connect("/home/manat/projects/obsq/work/dev/data/data.duckdb")

# %%
df = con.execute("SELECT * FROM raw.gbif_citizen").df()
df.head()
# Out:
#        gbifID                            datasetKey   occurrenceID  kingdom  \
# 0  3957383390  14d5676a-2c54-4f94-9023-1e8dcd822aa0  q-10652392282  Plantae
# 1  3952440098  14d5676a-2c54-4f94-9023-1e8dcd822aa0  q-10652312003  Plantae
# 2  3959814805  14d5676a-2c54-4f94-9023-1e8dcd822aa0  q-10652367517  Plantae
# 3  2646002583  14d5676a-2c54-4f94-9023-1e8dcd822aa0  q-10097979838  Plantae
# 4  3956638808  14d5676a-2c54-4f94-9023-1e8dcd822aa0  q-10095174312  Plantae
#
#          phylum           class         order           family        genus  \
# 0  Tracheophyta      Liliopsida        Poales          Poaceae          Zea
# 1  Tracheophyta   Magnoliopsida  Ranunculales     Papaveraceae  Sanguinaria
# 2  Tracheophyta  Polypodiopsida  Polypodiales  Dryopteridaceae  Polystichum
# 3  Tracheophyta   Magnoliopsida       Rosales         Rosaceae       Sorbus
# 4  Tracheophyta   Magnoliopsida       Rosales       Rhamnaceae      Rhamnus
#
# ...

# %%
con.close()
