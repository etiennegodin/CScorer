# %% [markdown]
# - Observer history (# observations, expertise indicators)
# - Image properties (count, quality proxies)
# - Community validation (# IDs, agreement rate)
# - Metadata completeness
# - Spatial precision
# - Rarity (common species = easier to ID correctly)
# - Phenological plausibility
# - Habitat match
